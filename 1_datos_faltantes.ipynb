# %% [markdown]
# # Datos Faltantes

# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.impute import SimpleImputer, KNNImputer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar el conjunto de datos
diabetes = load_diabetes(as_frame=True)
data = diabetes.data
data['target'] = diabetes.target

# %%
data.sample(10)

# %%
# Simular valores faltantes
np.random.seed(42)
data.loc[data.sample(frac=0.1).index, 'bmi'] = np.nan
data.loc[data.sample(frac=0.1).index, 'bp'] = np.nan

# %% [markdown]
# # Ejercicios
# Contesta las siguientes preguntas. Para cada pregunta, deberás escribir código que demostrará cómo llegaste al resultado:

# %% [markdown]
# ### 1. ¿Cuántos valores faltantes hay en cada columna?**

# %%
data.isna().sum()

# %% [markdown]
# ### 2. Utiliza imputación simple (media) para llenar los valores faltantes de la columna 'bmi'.

# %%
imputer = SimpleImputer(strategy='mean')
data['bmi_imputed'] = imputer.fit_transform(data[['bmi']])
data['bmi_imputed'].isnull().sum()

# %% [markdown]
# ### 3. Utiliza KNNImputer para imputar valores en las columnas 'bmi' y 'bp'. Compara los resultados con los de la imputación simple.

# %%
print("Media simple")
print(data['bmi_imputed'].mean())

print()

print("Media KNN")
print(data_knn['bmi'].mean())

# La imputación simple reemplaza todos los valores faltantes por una única media, 
# por lo que reduce la variabilidad de los datos. 
# En cambio, KNNImputer utiliza los valores de observaciones similares para estimar los faltantes, 
# conservando mejor la distribución original de los datos.

# %% [markdown]
# ### 4. Genera un histograma comparando los datos antes y después de la imputación en la columna 'bmi'.

# %%
plt.figure(figsize=(10,5))

plt.hist(
    bmi_original.dropna(),
    bins=20,
    alpha=0.5,
    label='Original'
)

plt.hist(
    data['bmi_imputed'],
    bins=20,
    alpha=0.5,
    label='Imputado'
)

plt.legend()

plt.xlabel("BMI")
plt.ylabel("Frecuencia")

plt.title("BMI antes y después de imputación")

plt.show()
